# %% [markdown]
# Q6.
# f. Implement extractive summarization using TextRank from gensim or sumy.

# %%
# Install required packages
# !pip install sumy transformers datasets

# %%
# Download NLTK 'punkt' tokenizer required by sumy
import nltk
nltk.download('punkt')

# Import libraries
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

# Sample text (replace with CNN/DailyMail article later)
text = """
Climate change refers to long-term shifts in temperatures and weather patterns.
Such shifts can be natural, due to changes in the sun’s activity or large volcanic eruptions.
But since the 1800s, human activities have been the main driver of climate change,
primarily due to burning fossil fuels like coal, oil, and gas.
"""

# Create a parser
parser = PlaintextParser.from_string(text, Tokenizer("english"))

# Initialize TextRank summarizer
summarizer = TextRankSummarizer()

# Extract top 2 sentences
summary_sentences = summarizer(parser.document, 2)

print("===== Extractive Summary =====")
for sentence in summary_sentences:
    print(sentence)
# Out:
# ===== Extractive Summary =====
# Such shifts can be natural, due to changes in the sun’s activity or large volcanic eruptions.
# But since the 1800s, human activities have been the main driver of climate change, primarily due to burning fossil fuels like coal, oil, and gas.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Q6. g. Implement abstractive summarization using Hugging Face transformers (e.g., facebook/bart-large-cnn).

# %%
# Import summarization pipeline
from transformers import pipeline

# Load summarization pipeline with BART model
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# Sample text (will replace with CNN/DailyMail article later)
text = """
Climate change refers to long-term shifts in temperatures and weather patterns.
Such shifts can be natural, due to changes in the sun’s activity or large volcanic eruptions.
But since the 1800s, human activities have been the main driver of climate change,
primarily due to burning fossil fuels like coal, oil, and gas.
"""

# Generate abstractive summary
summary = summarizer(text, max_length=50, min_length=20, do_sample=False)

print("===== Abstractive Summary =====")
print(summary[0]['summary_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# ===== Abstractive Summary =====
# ...

# %% [markdown]
# Q6. h. Dataset: CNN/DailyMail summarization dataset via Hugging Face: cnn_dailymail
# https://huggingface.co/datasets/cnn_dailymail

# %%
# Import load_dataset
from datasets import load_dataset

# Load a small subset for testing (first 100 articles from train split)
dataset = load_dataset("cnn_dailymail", "3.0.0", split="train[:100]")

# Display one sample article and its reference summary
sample = dataset[0]
print("\n===== Original Article =====\n", sample['article'])
print("\n===== Reference Summary =====\n", sample['highlights'])
# Out:
# ===== Original Article =====
# ...
